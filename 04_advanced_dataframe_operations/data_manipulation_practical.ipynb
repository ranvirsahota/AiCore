# %%
import pandas as pd
df = pd.read_csv('Salaries.csv')
df
# Out:
#      Id              EmployeeName  \
# 0    AA            NATHANIEL FORD
# 1    AB              GARY JIMENEZ
# 2    AC            ALBERT PARDINI
# 3    AD         CHRISTOPHER CHONG
# 4    AE           PATRICK GARDNER
# ..   ..                       ...
# 671  ZV              CHERYL ADAMS
# 672  ZW            LOUISE SIMPSON
# 673  ZX               BLAKE LOEBS
# 674  ZY  ELIZABETH AGUILAR-TARCHI
# 675  ZZ                 JULIAN NG
#
#                                            JobTitle    BasePay  OvertimePay  \
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                   CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                   CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3              WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ..                                              ...        ...          ...
# ...

# %% [markdown]
# 1. How many unique jobs are there? Look at the unique method in pandas.

# %%
len(df['JobTitle'].unique())
# Out:
# 93

# %% [markdown]
# 2. Count how many people have the first name "John"

# %%
(df['EmployeeName'].str.split(' ').str[0].str.lower() == 'john').sum()
# Out:
# 30

# %% [markdown]
# 3. Find the surname of everyone whose first name is more than 6 characters long

# %%
names_split = df['EmployeeName'].str.split(' ')
for name in names_split:
    if len(name[0]) > 6:
        print(name[1])
# Out:
# FORD
# CHONG
# GARDNER
# MORRIS
# JACKSON
# CORRIEA
# WONG
# SUHR
# GUZMAN
# WARD
# THOMPSON
# THOMPSON
# GARCIA
# ROLOVICH
# ROSENFIELD
# RIBA
# CHUNG
# SMITH
# CRANE
# MAR
# PARRY
# BUSALACCHI
# FREED
# MOYER
# FLORES
# DELANE
# GONZALEZ
# MYERS
# BAXTER
# BRYANT
# STANGLAND
# WALSH
# SCOTT
# ADAMS
# WONG
# ALI
# CASTAGNOLA
# MITCHELL
# JULIAN
# SAKOWSKI
# ROUALDES
# PUMPHREY
# LEMOS
# CARLIN
# STEWART
# DUMONT
# DENTONI
# CHOW
# CARR
# KEARNEY
# MCNAUGHTON
# YEE
# BIEL
# VERHAEG
# SCOTT
# BROWNE
# PEDRUCO
# LEE
# BARASH
# BALLOU
# CHEN
# HAZEN
# JEQUINTO
# RILEY
# AHERN
# SULLIVAN
# TRIPLETT
# PINTO
# GERMAN
# ELLIS
# SCHULTHEIS
# KOENIG
# TACCHINI
# RADER
# MCFARLAND
# AVILA
# CORRALES
# RYKOWSKI
# SIMMONS
# PARRA
# REYES
# DEALBA
# O'CONNER
# LEE
# CADELINA
# LERMA
# CHAVEZ
# BINKLEY
# ADACHI
# MATHEWS
# BRIGHAM
# HENNESSEY
# RAPADAS
# MCEACHERN
# CALLAHAN
# YOU
# TOPPS
# MENESES
# GONZALES
# ZMUDA
# DEBERRY
# WHOOLEY
# CACHARELIS
# MARX
# JAMES
# OSULLIVAN
# MOYNIHAN
# ...

# %% [markdown]
# 4. Create a new column called "last_updated" where every value is equal to the current time (use the datetime module and format the date in ISO format).

# %%
import datetime as dt
df['last_updated'] = dt.datetime.now().isoformat(' ')
df
# Out:
#      Id              EmployeeName  \
# 0    AA            NATHANIEL FORD
# 1    AB              GARY JIMENEZ
# 2    AC            ALBERT PARDINI
# 3    AD         CHRISTOPHER CHONG
# 4    AE           PATRICK GARDNER
# ..   ..                       ...
# 671  ZV              CHERYL ADAMS
# 672  ZW            LOUISE SIMPSON
# 673  ZX               BLAKE LOEBS
# 674  ZY  ELIZABETH AGUILAR-TARCHI
# 675  ZZ                 JULIAN NG
#
#                                            JobTitle    BasePay  OvertimePay  \
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                   CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                   CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3              WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ..                                              ...        ...          ...
# ...

# %% [markdown]
# 5. Create a new derived column called "time_ratio" in the DataFrame which is the proportion of overtime pay to base pay

# %%
df['time_ratio'] = (df['OvertimePay'] / df['BasePay']) * 100
df
# Out:
#      Id              EmployeeName  \
# 0    AA            NATHANIEL FORD
# 1    AB              GARY JIMENEZ
# 2    AC            ALBERT PARDINI
# 3    AD         CHRISTOPHER CHONG
# 4    AE           PATRICK GARDNER
# ..   ..                       ...
# 671  ZV              CHERYL ADAMS
# 672  ZW            LOUISE SIMPSON
# 673  ZX               BLAKE LOEBS
# 674  ZY  ELIZABETH AGUILAR-TARCHI
# 675  ZZ                 JULIAN NG
#
#                                            JobTitle    BasePay  OvertimePay  \
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                   CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                   CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3              WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ..                                              ...        ...          ...
# ...

# %% [markdown]
# 6. In one line, create a new DataFrame called "new_df" which contains only people who earn more than 100K base salary

# %%
new_df = df[df['BasePay'] > 100000]
new_df
# Out:
#      Id              EmployeeName  \
# 0    AA            NATHANIEL FORD
# 1    AB              GARY JIMENEZ
# 2    AC            ALBERT PARDINI
# 4    AE           PATRICK GARDNER
# 5    AF            DAVID SULLIVAN
# ..   ..                       ...
# 671  ZV              CHERYL ADAMS
# 672  ZW            LOUISE SIMPSON
# 673  ZX               BLAKE LOEBS
# 674  ZY  ELIZABETH AGUILAR-TARCHI
# 675  ZZ                 JULIAN NG
#
#                                            JobTitle    BasePay  OvertimePay  \
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                   CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                   CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 4      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# 5                         ASSISTANT DEPUTY CHIEF II  118602.00      8601.00
# ..                                              ...        ...          ...
# ...

# %% [markdown]
# 7. Now create a new derived column in "new_df" that is the sum of their pays, not including base salary

# %%
new_df['PaySumExlBaseSalary'] = new_df['TotalPayBenefits'] - new_df['BasePay']
new_df
# Out:
# /tmp/ipykernel_137946/444064668.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['PaySumExlBaseSalary'] = new_df['TotalPayBenefits'] - new_df['BasePay']
#      Id              EmployeeName  \
# 0    AA            NATHANIEL FORD
# 1    AB              GARY JIMENEZ
# 2    AC            ALBERT PARDINI
# 4    AE           PATRICK GARDNER
# 5    AF            DAVID SULLIVAN
# ..   ..                       ...
# 671  ZV              CHERYL ADAMS
# 672  ZW            LOUISE SIMPSON
# 673  ZX               BLAKE LOEBS
# 674  ZY  ELIZABETH AGUILAR-TARCHI
# 675  ZZ                 JULIAN NG
#
#                                            JobTitle    BasePay  OvertimePay  \
# ...

# %% [markdown]
# 8. Append a new row to the DataFrame to represent a made up character (you can use the pd.Concat() method for this)

# %%
import numpy as np

new_row = pd.DataFrame({
    'EmployeeName': ['Gojo Satoru'],
    'JobTitle': ['THE STRONGEST/TEACHER'],
    'BasePay': [1000000.00],
    'OvertimePay': [5000.00],
    'OtherPay': [2500.00],
    'Benefits': [float('nan')],
    'TotalPay': [107500.00],
    'TotalPayBenefits': [107500.00],
    'Year': [2023],
    'Notes': [float('nan')],
    'Agency': ['Japan'],
    'Status': np.nan
})

row_concat = pd.concat((new_df, new_row), ignore_index=True, )
row_concat
# Out:
#       Id              EmployeeName  \
# 0     AA            NATHANIEL FORD
# 1     AB              GARY JIMENEZ
# 2     AC            ALBERT PARDINI
# 3     AE           PATRICK GARDNER
# 4     AF            DAVID SULLIVAN
# ..   ...                       ...
# 613   ZW            LOUISE SIMPSON
# 614   ZX               BLAKE LOEBS
# 615   ZY  ELIZABETH AGUILAR-TARCHI
# 616   ZZ                 JULIAN NG
# 617  NaN               Gojo Satoru
#
#                                            JobTitle     BasePay  OvertimePay  \
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY   167411.18         0.00
# 1                   CAPTAIN III (POLICE DEPARTMENT)   155966.02    245131.88
# 2                   CAPTAIN III (POLICE DEPARTMENT)   212739.13    106088.18
# 3      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.60      9737.00
# 4                         ASSISTANT DEPUTY CHIEF II   118602.00      8601.00
# ...
