# %%
import pandas as pd
df = pd.read_csv('Salaries.csv')
df
# Out:
#      Id              EmployeeName  \
# 0    AA            NATHANIEL FORD
# 1    AB              GARY JIMENEZ
# 2    AC            ALBERT PARDINI
# 3    AD         CHRISTOPHER CHONG
# 4    AE           PATRICK GARDNER
# ..   ..                       ...
# 671  ZV              CHERYL ADAMS
# 672  ZW            LOUISE SIMPSON
# 673  ZX               BLAKE LOEBS
# 674  ZY  ELIZABETH AGUILAR-TARCHI
# 675  ZZ                 JULIAN NG
#
#                                            JobTitle    BasePay  OvertimePay  \
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                   CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                   CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3              WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ..                                              ...        ...          ...
# 671               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.18         0.00
# 672               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.18         0.00
# 673               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.19         0.00
# 674               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.17         0.00
# 675                SERGEANT III (POLICE DEPARTMENT)  130457.76     43793.11
#
#       OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 0    400184.25       NaN  567595.43         567595.43  2011    NaN
# 1    137811.38       NaN  538909.28         538909.28  2011    NaN
# 2     16452.60       NaN  335279.91         335279.91  2011    NaN
# 3    198306.90       NaN  332343.61         332343.61  2011    NaN
# 4    182234.59       NaN  326373.19         326373.19  2011    NaN
# ..         ...       ...        ...               ...   ...    ...
# 671    3537.89       NaN  180394.07         180394.07  2011    NaN
# 672    3537.80       NaN  180393.98         180393.98  2011    NaN
# 673    3537.75       NaN  180393.94         180393.94  2011    NaN
# 674    3537.11       NaN  180393.28         180393.28  2011    NaN
# 675    6061.80       NaN  180312.67         180312.67  2011    NaN
#
#             Agency  Status
# 0    San Francisco     NaN
# 1    San Francisco     NaN
# 2    San Francisco     NaN
# 3    San Francisco     NaN
# 4    San Francisco     NaN
# ..             ...     ...
# 671  San Francisco     NaN
# 672  San Francisco     NaN
# 673  San Francisco     NaN
# 674  San Francisco     NaN
# 675  San Francisco     NaN
#
# [676 rows x 13 columns]

# %% [markdown]
# 1. How many unique jobs are there? Look at the unique method in pandas.

# %%
len(df['JobTitle'].unique())
# Out:
# 93

# %% [markdown]
# 2. Count how many people have the first name "John"

# %%
(df['EmployeeName'].str.split(' ').str[0].str.lower() == 'john').sum()
# Out:
# 30

# %% [markdown]
# 3. Find the surname of everyone whose first name is more than 6 characters long

# %%
names_split = df['EmployeeName'].str.split(' ')
for name in names_split:
    if len(name[0]) > 6:
        print(name[1])
# Out:
# FORD
# CHONG
# GARDNER
# MORRIS
# JACKSON
# CORRIEA
# WONG
# SUHR
# GUZMAN
# WARD
# THOMPSON
# THOMPSON
# GARCIA
# ROLOVICH
# ROSENFIELD
# RIBA
# HUPKE
# PORTER
# NG
# GRIMESEY
# HILTON
# MCDEVITT
# ROSEN
# MARTIN
# GAUGER
# LEE
# LIU
# SALVESON
# AGUILAR-TARCHI

# %% [markdown]
# 4. Create a new column called "last_updated" where every value is equal to the current time (use the datetime module and format the date in ISO format).

# %%
import datetime as dt
df['last_updated'] = dt.datetime.now().isoformat(' ')
df
# Out:
#      Id              EmployeeName  \
# 0    AA            NATHANIEL FORD
# 1    AB              GARY JIMENEZ
# 2    AC            ALBERT PARDINI
# 3    AD         CHRISTOPHER CHONG
# 4    AE           PATRICK GARDNER
# ..   ..                       ...
# 671  ZV              CHERYL ADAMS
# 672  ZW            LOUISE SIMPSON
# 673  ZX               BLAKE LOEBS
# 674  ZY  ELIZABETH AGUILAR-TARCHI
# 675  ZZ                 JULIAN NG
#
#                                            JobTitle    BasePay  OvertimePay  \
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                   CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                   CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3              WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ..                                              ...        ...          ...
# 671               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.18         0.00
# 672               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.18         0.00
# 673               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.19         0.00
# 674               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.17         0.00
# 675                SERGEANT III (POLICE DEPARTMENT)  130457.76     43793.11
#
#       OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 0    400184.25       NaN  567595.43         567595.43  2011    NaN
# 1    137811.38       NaN  538909.28         538909.28  2011    NaN
# 2     16452.60       NaN  335279.91         335279.91  2011    NaN
# 3    198306.90       NaN  332343.61         332343.61  2011    NaN
# 4    182234.59       NaN  326373.19         326373.19  2011    NaN
# ..         ...       ...        ...               ...   ...    ...
# 671    3537.89       NaN  180394.07         180394.07  2011    NaN
# 672    3537.80       NaN  180393.98         180393.98  2011    NaN
# 673    3537.75       NaN  180393.94         180393.94  2011    NaN
# 674    3537.11       NaN  180393.28         180393.28  2011    NaN
# 675    6061.80       NaN  180312.67         180312.67  2011    NaN
#
#             Agency  Status                last_updated
# 0    San Francisco     NaN  2023-10-29 22:56:18.993844
# 1    San Francisco     NaN  2023-10-29 22:56:18.993844
# 2    San Francisco     NaN  2023-10-29 22:56:18.993844
# 3    San Francisco     NaN  2023-10-29 22:56:18.993844
# 4    San Francisco     NaN  2023-10-29 22:56:18.993844
# ..             ...     ...                         ...
# 671  San Francisco     NaN  2023-10-29 22:56:18.993844
# 672  San Francisco     NaN  2023-10-29 22:56:18.993844
# 673  San Francisco     NaN  2023-10-29 22:56:18.993844
# 674  San Francisco     NaN  2023-10-29 22:56:18.993844
# 675  San Francisco     NaN  2023-10-29 22:56:18.993844
#
# [676 rows x 14 columns]

# %% [markdown]
# 5. Create a new derived column called "time_ratio" in the DataFrame which is the proportion of overtime pay to base pay

# %%
df['time_ratio'] = (df['OvertimePay'] / df['BasePay']) * 100
df
# Out:
#      Id              EmployeeName  \
# 0    AA            NATHANIEL FORD
# 1    AB              GARY JIMENEZ
# 2    AC            ALBERT PARDINI
# 3    AD         CHRISTOPHER CHONG
# 4    AE           PATRICK GARDNER
# ..   ..                       ...
# 671  ZV              CHERYL ADAMS
# 672  ZW            LOUISE SIMPSON
# 673  ZX               BLAKE LOEBS
# 674  ZY  ELIZABETH AGUILAR-TARCHI
# 675  ZZ                 JULIAN NG
#
#                                            JobTitle    BasePay  OvertimePay  \
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                   CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                   CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3              WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ..                                              ...        ...          ...
# 671               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.18         0.00
# 672               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.18         0.00
# 673               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.19         0.00
# 674               HEAD ATTORNEY, CIVIL AND CRIMINAL  176856.17         0.00
# 675                SERGEANT III (POLICE DEPARTMENT)  130457.76     43793.11
#
#       OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 0    400184.25       NaN  567595.43         567595.43  2011    NaN
# 1    137811.38       NaN  538909.28         538909.28  2011    NaN
# 2     16452.60       NaN  335279.91         335279.91  2011    NaN
# 3    198306.90       NaN  332343.61         332343.61  2011    NaN
# 4    182234.59       NaN  326373.19         326373.19  2011    NaN
# ..         ...       ...        ...               ...   ...    ...
# 671    3537.89       NaN  180394.07         180394.07  2011    NaN
# 672    3537.80       NaN  180393.98         180393.98  2011    NaN
# 673    3537.75       NaN  180393.94         180393.94  2011    NaN
# 674    3537.11       NaN  180393.28         180393.28  2011    NaN
# 675    6061.80       NaN  180312.67         180312.67  2011    NaN
#
#             Agency  Status                last_updated  time_ratio
# 0    San Francisco     NaN  2023-10-29 22:56:18.993844    0.000000
# 1    San Francisco     NaN  2023-10-29 22:56:18.993844    1.571701
# 2    San Francisco     NaN  2023-10-29 22:56:18.993844    0.498677
# 3    San Francisco     NaN  2023-10-29 22:56:18.993844    0.720272
# 4    San Francisco     NaN  2023-10-29 22:56:18.993844    0.072447
# ..             ...     ...                         ...         ...
# 671  San Francisco     NaN  2023-10-29 22:56:18.993844    0.000000
# 672  San Francisco     NaN  2023-10-29 22:56:18.993844    0.000000
# 673  San Francisco     NaN  2023-10-29 22:56:18.993844    0.000000
# 674  San Francisco     NaN  2023-10-29 22:56:18.993844    0.000000
# 675  San Francisco     NaN  2023-10-29 22:56:18.993844    0.335688
#
# [676 rows x 15 columns]
